# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/Actividades_Aprendizaje-A01794023-Andres_Palacios/blob/main/Data_Analysis_with_Python_(IBM)_Module4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Data Analysis with Python (IBM): Module4**
#
# **Asignatura: Ciencia y Analitica de datos**
#
# **Nombre: Jaime Andres Palacios Campaña**
#
# **Matricula: A01794023**

# %% [markdown]
# **Model Development**
#
# -  A model or estimator can be thought of as a mathematical equation used to predict a value given one or more other values.
# -  Relating one or more independent variables or features to dependent variables.

# %% [markdown]
# ## **Descriptive Statistics**

# %%
import pandas as pd #Importamos la libreria de Pandas
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data'
df = pd.read_csv(url, header=None)  #Creamos el dataframe con el csv de url, no tiene columnas titulos.

# creamos una lista con los headers manualmente para luego agregarlos al df
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]

df.columns=headers #agregamos a la lista 'headers' como headers.

# %%
from contextlib import nullcontext
df = df.replace(['?'],[np.NaN])
df['price'] = df['price'].astype('float64')

df = df.dropna()

# %% [markdown]
# ##Linear and Multiple Linear Regression

# %%
X = df[['highway-mpg']]
Y = df[['price']]

# %%
reg = LinearRegression().fit(X,Y)

# %%
Yhat = reg.predict(X)

# %%
reg.intercept_,reg.coef_
# Out:
# (array([32468.309406]), array([[-655.28135573]]))

# %%
sns.regplot(x='highway-mpg', y='price', data=df)
plt.ylim(0,)
# Out:
# (0.0, 37135.060018350625)

# %%
sns.residplot(df['highway-mpg'], df['price'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
from sklearn.metrics import mean_squared_error

reg.score(X,Y)
# Out:
# 0.5185297491395178

# %% [markdown]
# #Graded Review Questions

# %% [markdown]
# ![Modulo 4.JPG](data:image/jpeg;base64,...)
